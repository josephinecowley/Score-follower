# %%
import sys
sys.path.append('/Users/josephine/Documents/Engineering /Part IIB/Score alignment project/Score-follower/final/GP_models')
import helper
from numpy.linalg import inv
import numpy as np
from matplotlib import pyplot as plt
import scipy.io.wavfile as wav
from numpy.linalg import cholesky, det
from scipy.linalg import solve_triangular

# %%
wav_file = '/Users/josephine/Documents/Engineering /Part IIB/Score alignment project/Score-follower/wav_files/A_440_piano.wav'
sample_rate, data = wav.read(wav_file)
audio_duration = len(data)/sample_rate
time_samples = np.linspace(0, audio_duration, len(data))
helper.plot_audio(time_samples, data, title="Single A4 (440 Hz) piano note")
# Out:
# /var/folders/n4/k97yk30s1wn32d7y6729kph80000gn/T/ipykernel_14274/1774353469.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = wav.read(wav_file)

# %%
wav_file = '/Users/josephine/Documents/Engineering /Part IIB/Score alignment project/Score-follower/wav_files/A_440_piano.wav'
sample_rate, data = wav.read(wav_file)
data = data[8000:9000]
audio_duration = len(data)/sample_rate
time_samples = np.linspace(0, audio_duration, len(data))
helper.plot_audio(time_samples, data, title="1000 samples of single A4 (440 Hz) piano note")
# Out:
# /var/folders/n4/k97yk30s1wn32d7y6729kph80000gn/T/ipykernel_14274/2780630328.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = wav.read(wav_file)

# %%
wav_file = '/Users/josephine/Documents/Engineering /Part IIB/Score alignment project/Score-follower/wav_files/piano_E4_330.wav'
sample_rate, data = wav.read(wav_file)
audio_duration = len(data)/sample_rate
time_samples = np.linspace(0, audio_duration, len(data))
helper.plot_audio(time_samples, data, title="1000 samples of single E4 (330 Hz) piano note")
# Out:
# /var/folders/n4/k97yk30s1wn32d7y6729kph80000gn/T/ipykernel_14274/1227409357.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = wav.read(wav_file)

# %%
wav_file = '/Users/josephine/Documents/Engineering /Part IIB/Score alignment project/Score-follower/wav_files/piano_E4_330.wav'
sample_rate, data = wav.read(wav_file)
data = data[4000:5000]
audio_duration = len(data)/sample_rate
time_samples = np.linspace(0, audio_duration, len(data))
helper.plot_audio(time_samples, data, title="1000 samples of single E4 (330 Hz) piano note")
# Out:
# /var/folders/n4/k97yk30s1wn32d7y6729kph80000gn/T/ipykernel_14274/4082678733.py:4: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = wav.read(wav_file)

# %%
### Purely just experimenting with SM_kernel 
sample_rate = 44100
sample_len = 3000
audio_duration = sample_len/sample_rate
x = np.linspace(0, sample_rate, sample_len)

K = helper.SM_kernel(x,x, f=[220, 758], sigma_f=1/50000)
helper.plot_kernel_matrix(K)
print(np.linalg.det(K))
# Out:
# 2it [00:01,  1.18it/s]
# 0.0
