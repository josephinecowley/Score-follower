# %%
import sys
sys.path.append('/Users/josephine/Documents/Engineering /Part IIB/Score alignment project/Score-follower/final/experiments')
import GP_helper
import numpy as np
import scipy.io.wavfile as wav

# %%
wav_file = '/Users/josephine/Documents/Engineering /Part IIB/Score alignment project/Score-follower/final/experiments/experiment_wav_files/A_440_piano.wav'
sample_rate, data = wav.read(wav_file)
audio_duration = len(data)/sample_rate
time_samples = np.linspace(0, audio_duration, len(data))
GP_helper.plot_fft(data)
# Out:
# /var/folders/n4/k97yk30s1wn32d7y6729kph80000gn/T/ipykernel_15414/1570689124.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = wav.read(wav_file)

# %%
wav_file = '/Users/josephine/Documents/Engineering /Part IIB/Score alignment project/Score-follower/final/experiments/experiment_wav_files/A_440_piano.wav'
sample_rate, data = wav.read(wav_file)
data = data[2000:4000]
audio_duration = len(data)/sample_rate
time_samples = np.linspace(0, audio_duration, len(data))
GP_helper.plot_fft(data, title="FFT of 2000 samples  a single A4 (440 Hz) piano note — Hanning window")
# Out:
# /var/folders/n4/k97yk30s1wn32d7y6729kph80000gn/T/ipykernel_15414/3407025925.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = wav.read(wav_file)

# %%
wav_file = '/Users/josephine/Documents/Engineering /Part IIB/Score alignment project/Score-follower/final/experiments/experiment_wav_files/A_440_piano.wav'
sample_rate, data = wav.read(wav_file)
data = data[5000:7000]
audio_duration = len(data)/sample_rate
time_samples = np.linspace(0, audio_duration, len(data))
GP_helper.plot_fft(data, title="PSD of 2000 samples  a single A4 (440 Hz) piano note — Hanning window", power_spectrum=True)
# Out:
# /var/folders/n4/k97yk30s1wn32d7y6729kph80000gn/T/ipykernel_15414/2657412757.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = wav.read(wav_file)
